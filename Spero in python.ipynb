# %%
import nltk  
nltk.download('stopwords')  
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import xlrd
file_name = 'De-identified student comments.xlsx'

import pandas as pd
df = pd.read_excel(io=file_name,sheets = sheet_name)
#print(df.head)

df = df.dropna(axis=0, how="any")

# %%
from nltk.tokenize import word_tokenize

positive = pd.read_excel(file_name, sheetname='POSITIVE')
negative = pd.read_excel(file_name, sheetname='NEGATIVE')

sent_positive = positive.to_string(index=False)
sent_negative = negative.to_string(index=False)

positive_tokens = word_tokenize(sent_positive)
negative_tokens = word_tokenize(sent_negative)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/util/_decorators.py:188: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
# ...

# %%
#import the nltk package
import nltk
#call the nltk downloader
nltk.download('punkt')
from nltk.stem.porter import * 

from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
import re
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
stemmer = PorterStemmer()
stop_words = set(stopwords.words('english')) 


rows = list()
wholedata = " "
filtered_sentence = []
stemmed_sentence = []

for row in df[['HELPFUL', 'IMPROVE']].iterrows():
    r = row[1]
    data =r.get_values()[0]
    lower = data.lower()
    reg = re.sub('[^A-Za-z0-9]+', ' ', lower) 
    word_tokens = word_tokenize(reg) 
    #print(word_tokens)
    wholedata = str(wholedata)+ " "+str(word_tokens)
    filtered_sentence = [w for w in word_tokens if not w in stop_words] 
    #print(filtered_sentence)
    
    for w in word_tokens: 
       if w not in stop_words: 
        filtered_sentence.append(w) 
  
    #print(word_tokens)
    #print(filtered_sentence)    

    for token in filtered_sentence:  
      #print(token)
      stemmed_sentence.append(stemmer.stem(token))
stemmed_sentence
# Out:
# ['onlin',
#  'test',
#  'extrem',
#  'help',
#  'end',
#  'lectur',
#  'help',
#  'get',
#  'better',
#  'understand',
#  'concept',
#  'lectur',
#  'great',
#  'never',
#  'bore',
#  'like',
#  'given',
#  'exampl',
#  'exam',
#  'question',
#  'benefici',
#  'could',
#  'focu',
#  'area',
#  'studi',
#  'onlin',
#  'test',
#  'extrem',
#  'help',
#  'end',
#  'lectur',
#  'help',
#  'get',
#  'better',
#  'understand',
#  'concept',
#  'lectur',
#  'great',
#  'never',
#  'bore',
#  'like',
#  'given',
#  'exampl',
#  'exam',
#  'question',
#  'benefici',
#  'could',
#  'focu',
#  'area',
#  'studi',
#  'extrem',
#  'well',
#  'organis',
#  'day',
#  'one',
#  'extrem',
#  'well',
#  'organis',
#  'day',
#  'one',
#  'commit',
#  'attent',
#  'person',
#  'insight',
#  'provid',
#  'unit',
#  'chair',
#  'teach',
#  'lectur',
#  'abil',
#  'translat',
#  'dri',
#  'complex',
#  'subject',
#  'matter',
#  'pretti',
#  'memor',
#  'exampl',
#  'featur',
#  'nissan',
#  'bluebird',
# ...

# %%
import gensim
from gensim.utils import tokenize
from gensim.models import Word2Vec


model = Word2Vec(df)

words = list(model.wv.vocab)
print(words)


#model.wv.most_similar(positive='feedback')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-254-07b7e988c1a7> in <module>()
#       4
#       5
# ----> 6 model = Word2Vec(df)
#       7
#       8 words = list(model.wv.vocab)
#
# /usr/local/lib/python3.6/dist-packages/gensim/models/word2vec.py in __init__(self, sentences, corpus_file, size, alpha, window, min_count, max_vocab_size, sample, seed, workers, min_alpha, sg, hs, negative, ns_exponent, cbow_mean, hashfxn, iter, null_word, trim_rule, sorted_vocab, batch_words, compute_loss, callbacks, max_final_vocab)
#     765             callbacks=callbacks, batch_words=batch_words, trim_rule=trim_rule, sg=sg, alpha=alpha, window=window,
#     766             seed=seed, hs=hs, negative=negative, cbow_mean=cbow_mean, min_alpha=min_alpha, compute_loss=compute_loss,
# --> 767             fast_version=FAST_VERSION)
#     768
# ...
